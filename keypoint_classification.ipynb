# %%
import csv

import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split

RANDOM_SEED = 42

# %% [markdown]
# # 各パス指定

# %%
dataset = 'model/keypoint_classifier/keypoint.csv'
model_save_path = 'model/keypoint_classifier/keypoint_classifier.hdf5'

# %% [markdown]
# # 分類数設定

# %%
NUM_CLASSES = 4

# %% [markdown]
# # 学習データ読み込み

# %%
X_dataset = np.loadtxt(dataset, delimiter=',', dtype='float32', usecols=list(range(1, (21 * 2) + 1)))

# %%
y_dataset = np.loadtxt(dataset, delimiter=',', dtype='int32', usecols=(0))

# %%
X_train, X_test, y_train, y_test = train_test_split(X_dataset, y_dataset, train_size=0.75, random_state=RANDOM_SEED)

# %% [markdown]
# # モデル構築

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Input((21 * 2, )),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(20, activation='relu'),
    tf.keras.layers.Dropout(0.4),
    tf.keras.layers.Dense(10, activation='relu'),
    tf.keras.layers.Dense(NUM_CLASSES, activation='softmax')
])

# %%
model.summary()  # tf.keras.utils.plot_model(model, show_shapes=True)
# Out:
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dropout_20 (Dropout)        (None, 42)                0
#
#  dense_30 (Dense)            (None, 20)                860
#
#  dropout_21 (Dropout)        (None, 20)                0
#
#  dense_31 (Dense)            (None, 10)                210
#
#  dense_32 (Dense)            (None, 4)                 44
#
# =================================================================
# Total params: 1,114
# Trainable params: 1,114
# Non-trainable params: 0
# _________________________________________________________________

# %%
# モデルチェックポイントのコールバック
cp_callback = tf.keras.callbacks.ModelCheckpoint(
    model_save_path, verbose=1, save_weights_only=False)
# 早期打ち切り用コールバック
es_callback = tf.keras.callbacks.EarlyStopping(patience=20, verbose=1)

# %%
# モデルコンパイル
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %% [markdown]
# # モデル訓練

# %%
model.fit(
    X_train,
    y_train,
    epochs=1000,
    batch_size=128,
    validation_data=(X_test, y_test),
    callbacks=[cp_callback, es_callback]
)
# Out:
# Epoch 1/1000
# 29/30 [============================>.] - ETA: 0s - loss: 1.5383 - accuracy: 0.2662
# Epoch 1: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 1s 8ms/step - loss: 1.5368 - accuracy: 0.2668 - val_loss: 1.3499 - val_accuracy: 0.3245
# Epoch 2/1000
# 28/30 [===========================>..] - ETA: 0s - loss: 1.3470 - accuracy: 0.3454
# Epoch 2: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 1.3455 - accuracy: 0.3475 - val_loss: 1.2887 - val_accuracy: 0.3838
# Epoch 3/1000
# 28/30 [===========================>..] - ETA: 0s - loss: 1.2960 - accuracy: 0.3859
# Epoch 3: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 1.2979 - accuracy: 0.3839 - val_loss: 1.2366 - val_accuracy: 0.4311
# Epoch 4/1000
# 29/30 [============================>.] - ETA: 0s - loss: 1.2606 - accuracy: 0.3995
# Epoch 4: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 1.2602 - accuracy: 0.3994 - val_loss: 1.1921 - val_accuracy: 0.4816
# Epoch 5/1000
# 29/30 [============================>.] - ETA: 0s - loss: 1.2256 - accuracy: 0.4178
# Epoch 5: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 1.2260 - accuracy: 0.4175 - val_loss: 1.1450 - val_accuracy: 0.5441
# Epoch 6/1000
# 28/30 [===========================>..] - ETA: 0s - loss: 1.1790 - accuracy: 0.4517
# Epoch 6: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 1.1771 - accuracy: 0.4536 - val_loss: 1.0939 - val_accuracy: 0.5649
# Epoch 7/1000
# 29/30 [============================>.] - ETA: 0s - loss: 1.1423 - accuracy: 0.4731
# Epoch 7: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 1.1406 - accuracy: 0.4742 - val_loss: 1.0422 - val_accuracy: 0.5697
# Epoch 8/1000
# 28/30 [===========================>..] - ETA: 0s - loss: 1.1023 - accuracy: 0.4922
# Epoch 8: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 1.1011 - accuracy: 0.4956 - val_loss: 0.9700 - val_accuracy: 0.5978
# Epoch 9/1000
# 28/30 [===========================>..] - ETA: 0s - loss: 1.0860 - accuracy: 0.5025
# Epoch 9: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 1.0846 - accuracy: 0.5047 - val_loss: 0.9233 - val_accuracy: 0.6058
# Epoch 10/1000
# 28/30 [===========================>..] - ETA: 0s - loss: 1.0452 - accuracy: 0.5176
# Epoch 10: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 1.0454 - accuracy: 0.5167 - val_loss: 0.8789 - val_accuracy: 0.6122
# Epoch 11/1000
# 29/30 [============================>.] - ETA: 0s - loss: 1.0097 - accuracy: 0.5498
# Epoch 11: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 1.0092 - accuracy: 0.5509 - val_loss: 0.8384 - val_accuracy: 0.6490
# Epoch 12/1000
# 29/30 [============================>.] - ETA: 0s - loss: 0.9852 - accuracy: 0.5684
# Epoch 12: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.9854 - accuracy: 0.5694 - val_loss: 0.7988 - val_accuracy: 0.7083
# Epoch 13/1000
# 27/30 [==========================>...] - ETA: 0s - loss: 0.9630 - accuracy: 0.5819
# Epoch 13: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.9601 - accuracy: 0.5862 - val_loss: 0.7645 - val_accuracy: 0.7596
# Epoch 14/1000
# 28/30 [===========================>..] - ETA: 0s - loss: 0.9558 - accuracy: 0.5820
# Epoch 14: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.9499 - accuracy: 0.5870 - val_loss: 0.7388 - val_accuracy: 0.7845
# Epoch 15/1000
# 29/30 [============================>.] - ETA: 0s - loss: 0.9173 - accuracy: 0.6037
# Epoch 15: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.9176 - accuracy: 0.6036 - val_loss: 0.7109 - val_accuracy: 0.7925
# Epoch 16/1000
# 29/30 [============================>.] - ETA: 0s - loss: 0.8974 - accuracy: 0.6188
# Epoch 16: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.8978 - accuracy: 0.6183 - val_loss: 0.6825 - val_accuracy: 0.8165
# Epoch 17/1000
# 29/30 [============================>.] - ETA: 0s - loss: 0.8846 - accuracy: 0.6237
# Epoch 17: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.8840 - accuracy: 0.6236 - val_loss: 0.6640 - val_accuracy: 0.8197
# Epoch 18/1000
# 30/30 [==============================] - ETA: 0s - loss: 0.8739 - accuracy: 0.6333
# Epoch 18: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.8739 - accuracy: 0.6333 - val_loss: 0.6370 - val_accuracy: 0.8381
# Epoch 19/1000
# 30/30 [==============================] - ETA: 0s - loss: 0.8508 - accuracy: 0.6450
# Epoch 19: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.8508 - accuracy: 0.6450 - val_loss: 0.6191 - val_accuracy: 0.8574
# Epoch 20/1000
# 27/30 [==========================>...] - ETA: 0s - loss: 0.8519 - accuracy: 0.6522
# Epoch 20: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.8517 - accuracy: 0.6528 - val_loss: 0.6024 - val_accuracy: 0.8582
# Epoch 21/1000
# 28/30 [===========================>..] - ETA: 0s - loss: 0.8239 - accuracy: 0.6655
# Epoch 21: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.8215 - accuracy: 0.6677 - val_loss: 0.5854 - val_accuracy: 0.8646
# Epoch 22/1000
# 29/30 [============================>.] - ETA: 0s - loss: 0.8120 - accuracy: 0.6765
# Epoch 22: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.8103 - accuracy: 0.6779 - val_loss: 0.5660 - val_accuracy: 0.8710
# Epoch 23/1000
# 26/30 [=========================>....] - ETA: 0s - loss: 0.7894 - accuracy: 0.6839
# Epoch 23: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.7953 - accuracy: 0.6816 - val_loss: 0.5438 - val_accuracy: 0.8790
# Epoch 24/1000
# 27/30 [==========================>...] - ETA: 0s - loss: 0.7967 - accuracy: 0.6811
# Epoch 24: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.7982 - accuracy: 0.6795 - val_loss: 0.5347 - val_accuracy: 0.8862
# Epoch 25/1000
# 27/30 [==========================>...] - ETA: 0s - loss: 0.7834 - accuracy: 0.6942
# Epoch 25: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.7794 - accuracy: 0.6953 - val_loss: 0.5248 - val_accuracy: 0.8998
# Epoch 26/1000
# 28/30 [===========================>..] - ETA: 0s - loss: 0.7731 - accuracy: 0.6964
# Epoch 26: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.7707 - accuracy: 0.6979 - val_loss: 0.5043 - val_accuracy: 0.9038
# Epoch 27/1000
# 28/30 [===========================>..] - ETA: 0s - loss: 0.7593 - accuracy: 0.7028
# Epoch 27: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.7604 - accuracy: 0.7020 - val_loss: 0.4907 - val_accuracy: 0.9095
# Epoch 28/1000
# 29/30 [============================>.] - ETA: 0s - loss: 0.7313 - accuracy: 0.7206
# Epoch 28: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.7318 - accuracy: 0.7201 - val_loss: 0.4738 - val_accuracy: 0.9151
# Epoch 29/1000
# 28/30 [===========================>..] - ETA: 0s - loss: 0.7476 - accuracy: 0.7048
# Epoch 29: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.7436 - accuracy: 0.7078 - val_loss: 0.4629 - val_accuracy: 0.9119
# Epoch 30/1000
# 29/30 [============================>.] - ETA: 0s - loss: 0.7125 - accuracy: 0.7266
# Epoch 30: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.7121 - accuracy: 0.7273 - val_loss: 0.4488 - val_accuracy: 0.9263
# Epoch 31/1000
# 29/30 [============================>.] - ETA: 0s - loss: 0.7177 - accuracy: 0.7193
# Epoch 31: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.7159 - accuracy: 0.7204 - val_loss: 0.4347 - val_accuracy: 0.9255
# Epoch 32/1000
# 29/30 [============================>.] - ETA: 0s - loss: 0.7005 - accuracy: 0.7239
# Epoch 32: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.7004 - accuracy: 0.7239 - val_loss: 0.4250 - val_accuracy: 0.9359
# Epoch 33/1000
# 29/30 [============================>.] - ETA: 0s - loss: 0.7114 - accuracy: 0.7263
# Epoch 33: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.7115 - accuracy: 0.7263 - val_loss: 0.4163 - val_accuracy: 0.9367
# Epoch 34/1000
# 29/30 [============================>.] - ETA: 0s - loss: 0.6861 - accuracy: 0.7384
# Epoch 34: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.6861 - accuracy: 0.7380 - val_loss: 0.4063 - val_accuracy: 0.9383
# Epoch 35/1000
# 30/30 [==============================] - ETA: 0s - loss: 0.6805 - accuracy: 0.7396
# Epoch 35: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.6805 - accuracy: 0.7396 - val_loss: 0.3999 - val_accuracy: 0.9375
# Epoch 36/1000
# 26/30 [=========================>....] - ETA: 0s - loss: 0.6963 - accuracy: 0.7365
# Epoch 36: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.6928 - accuracy: 0.7378 - val_loss: 0.3942 - val_accuracy: 0.9407
# Epoch 37/1000
# 28/30 [===========================>..] - ETA: 0s - loss: 0.6560 - accuracy: 0.7453
# Epoch 37: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.6529 - accuracy: 0.7469 - val_loss: 0.3839 - val_accuracy: 0.9391
# Epoch 38/1000
# 25/30 [========================>.....] - ETA: 0s - loss: 0.6817 - accuracy: 0.7391
# Epoch 38: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 5ms/step - loss: 0.6779 - accuracy: 0.7410 - val_loss: 0.3774 - val_accuracy: 0.9439
# Epoch 39/1000
# 29/30 [============================>.] - ETA: 0s - loss: 0.6627 - accuracy: 0.7487
# Epoch 39: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.6628 - accuracy: 0.7490 - val_loss: 0.3676 - val_accuracy: 0.9415
# Epoch 40/1000
# 29/30 [============================>.] - ETA: 0s - loss: 0.6474 - accuracy: 0.7487
# Epoch 40: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.6477 - accuracy: 0.7479 - val_loss: 0.3651 - val_accuracy: 0.9439
# Epoch 41/1000
# 28/30 [===========================>..] - ETA: 0s - loss: 0.6476 - accuracy: 0.7575
# Epoch 41: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.6476 - accuracy: 0.7576 - val_loss: 0.3600 - val_accuracy: 0.9455
# Epoch 42/1000
# 23/30 [======================>.......] - ETA: 0s - loss: 0.6450 - accuracy: 0.7524
# Epoch 42: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 5ms/step - loss: 0.6401 - accuracy: 0.7517 - val_loss: 0.3540 - val_accuracy: 0.9431
# Epoch 43/1000
# 30/30 [==============================] - ETA: 0s - loss: 0.6433 - accuracy: 0.7600
# Epoch 43: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.6433 - accuracy: 0.7600 - val_loss: 0.3460 - val_accuracy: 0.9423
# Epoch 44/1000
# 28/30 [===========================>..] - ETA: 0s - loss: 0.6299 - accuracy: 0.7648
# Epoch 44: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.6357 - accuracy: 0.7637 - val_loss: 0.3376 - val_accuracy: 0.9471
# Epoch 45/1000
# 28/30 [===========================>..] - ETA: 0s - loss: 0.6364 - accuracy: 0.7609
# Epoch 45: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.6399 - accuracy: 0.7592 - val_loss: 0.3377 - val_accuracy: 0.9495
# Epoch 46/1000
# 29/30 [============================>.] - ETA: 0s - loss: 0.6414 - accuracy: 0.7586
# Epoch 46: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.6416 - accuracy: 0.7581 - val_loss: 0.3342 - val_accuracy: 0.9503
# Epoch 47/1000
# 27/30 [==========================>...] - ETA: 0s - loss: 0.6333 - accuracy: 0.7613
# Epoch 47: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.6316 - accuracy: 0.7637 - val_loss: 0.3345 - val_accuracy: 0.9455
# Epoch 48/1000
# 25/30 [========================>.....] - ETA: 0s - loss: 0.6183 - accuracy: 0.7616
# Epoch 48: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 5ms/step - loss: 0.6232 - accuracy: 0.7592 - val_loss: 0.3274 - val_accuracy: 0.9455
# Epoch 49/1000
# 23/30 [======================>.......] - ETA: 0s - loss: 0.6267 - accuracy: 0.7599
# Epoch 49: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 5ms/step - loss: 0.6167 - accuracy: 0.7677 - val_loss: 0.3225 - val_accuracy: 0.9479
# Epoch 50/1000
# 23/30 [======================>.......] - ETA: 0s - loss: 0.6073 - accuracy: 0.7734
# Epoch 50: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 5ms/step - loss: 0.5943 - accuracy: 0.7805 - val_loss: 0.3186 - val_accuracy: 0.9439
# Epoch 51/1000
# 25/30 [========================>.....] - ETA: 0s - loss: 0.5981 - accuracy: 0.7791
# Epoch 51: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.5944 - accuracy: 0.7811 - val_loss: 0.3054 - val_accuracy: 0.9479
# Epoch 52/1000
# 24/30 [=======================>......] - ETA: 0s - loss: 0.5836 - accuracy: 0.7799
# Epoch 52: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.5920 - accuracy: 0.7789 - val_loss: 0.3010 - val_accuracy: 0.9495
# Epoch 53/1000
# 27/30 [==========================>...] - ETA: 0s - loss: 0.6098 - accuracy: 0.7671
# Epoch 53: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.6098 - accuracy: 0.7669 - val_loss: 0.3024 - val_accuracy: 0.9535
# Epoch 54/1000
# 27/30 [==========================>...] - ETA: 0s - loss: 0.5892 - accuracy: 0.7755
# Epoch 54: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.5894 - accuracy: 0.7765 - val_loss: 0.2976 - val_accuracy: 0.9535
# Epoch 55/1000
# 28/30 [===========================>..] - ETA: 0s - loss: 0.5853 - accuracy: 0.7874
# Epoch 55: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.5878 - accuracy: 0.7870 - val_loss: 0.2916 - val_accuracy: 0.9511
# Epoch 56/1000
# 27/30 [==========================>...] - ETA: 0s - loss: 0.5930 - accuracy: 0.7746
# Epoch 56: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.5896 - accuracy: 0.7760 - val_loss: 0.2896 - val_accuracy: 0.9495
# Epoch 57/1000
# 29/30 [============================>.] - ETA: 0s - loss: 0.5944 - accuracy: 0.7732
# Epoch 57: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.5933 - accuracy: 0.7739 - val_loss: 0.2960 - val_accuracy: 0.9439
# Epoch 58/1000
# 26/30 [=========================>....] - ETA: 0s - loss: 0.5938 - accuracy: 0.7816
# Epoch 58: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.5909 - accuracy: 0.7821 - val_loss: 0.2920 - val_accuracy: 0.9479
# Epoch 59/1000
# 28/30 [===========================>..] - ETA: 0s - loss: 0.5756 - accuracy: 0.7921
# Epoch 59: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.5747 - accuracy: 0.7918 - val_loss: 0.2852 - val_accuracy: 0.9543
# Epoch 60/1000
# 28/30 [===========================>..] - ETA: 0s - loss: 0.5752 - accuracy: 0.7944
# Epoch 60: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.5759 - accuracy: 0.7939 - val_loss: 0.2826 - val_accuracy: 0.9551
# Epoch 61/1000
# 28/30 [===========================>..] - ETA: 0s - loss: 0.5618 - accuracy: 0.7946
# Epoch 61: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.5680 - accuracy: 0.7907 - val_loss: 0.2737 - val_accuracy: 0.9583
# Epoch 62/1000
# 28/30 [===========================>..] - ETA: 0s - loss: 0.6005 - accuracy: 0.7732
# Epoch 62: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.5972 - accuracy: 0.7755 - val_loss: 0.2814 - val_accuracy: 0.9463
# Epoch 63/1000
# 29/30 [============================>.] - ETA: 0s - loss: 0.5934 - accuracy: 0.7767
# Epoch 63: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.5918 - accuracy: 0.7776 - val_loss: 0.2807 - val_accuracy: 0.9479
# Epoch 64/1000
# 27/30 [==========================>...] - ETA: 0s - loss: 0.5730 - accuracy: 0.7882
# Epoch 64: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.5703 - accuracy: 0.7894 - val_loss: 0.2777 - val_accuracy: 0.9567
# Epoch 65/1000
# 29/30 [============================>.] - ETA: 0s - loss: 0.5752 - accuracy: 0.7826
# Epoch 65: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.5748 - accuracy: 0.7827 - val_loss: 0.2765 - val_accuracy: 0.9567
# Epoch 66/1000
# 28/30 [===========================>..] - ETA: 0s - loss: 0.5720 - accuracy: 0.7935
# Epoch 66: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.5709 - accuracy: 0.7934 - val_loss: 0.2758 - val_accuracy: 0.9519
# Epoch 67/1000
# 27/30 [==========================>...] - ETA: 0s - loss: 0.5733 - accuracy: 0.7879
# Epoch 67: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.5729 - accuracy: 0.7880 - val_loss: 0.2684 - val_accuracy: 0.9583
# Epoch 68/1000
# 27/30 [==========================>...] - ETA: 0s - loss: 0.5538 - accuracy: 0.7980
# Epoch 68: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.5528 - accuracy: 0.7987 - val_loss: 0.2697 - val_accuracy: 0.9527
# Epoch 69/1000
# 27/30 [==========================>...] - ETA: 0s - loss: 0.5576 - accuracy: 0.7917
# Epoch 69: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.5552 - accuracy: 0.7926 - val_loss: 0.2650 - val_accuracy: 0.9559
# Epoch 70/1000
# 26/30 [=========================>....] - ETA: 0s - loss: 0.5582 - accuracy: 0.7945
# Epoch 70: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.5614 - accuracy: 0.7910 - val_loss: 0.2629 - val_accuracy: 0.9527
# Epoch 71/1000
# 29/30 [============================>.] - ETA: 0s - loss: 0.5495 - accuracy: 0.8020
# Epoch 71: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.5476 - accuracy: 0.8027 - val_loss: 0.2657 - val_accuracy: 0.9535
# Epoch 72/1000
# 27/30 [==========================>...] - ETA: 0s - loss: 0.5606 - accuracy: 0.7920
# Epoch 72: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.5636 - accuracy: 0.7902 - val_loss: 0.2603 - val_accuracy: 0.9551
# Epoch 73/1000
# 28/30 [===========================>..] - ETA: 0s - loss: 0.5630 - accuracy: 0.7905
# Epoch 73: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.5651 - accuracy: 0.7886 - val_loss: 0.2583 - val_accuracy: 0.9535
# Epoch 74/1000
# 29/30 [============================>.] - ETA: 0s - loss: 0.5473 - accuracy: 0.7893
# Epoch 74: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.5472 - accuracy: 0.7896 - val_loss: 0.2543 - val_accuracy: 0.9559
# Epoch 75/1000
# 26/30 [=========================>....] - ETA: 0s - loss: 0.5591 - accuracy: 0.7912
# Epoch 75: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.5604 - accuracy: 0.7918 - val_loss: 0.2574 - val_accuracy: 0.9551
# Epoch 76/1000
# 28/30 [===========================>..] - ETA: 0s - loss: 0.5509 - accuracy: 0.7955
# Epoch 76: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.5469 - accuracy: 0.7971 - val_loss: 0.2571 - val_accuracy: 0.9535
# Epoch 77/1000
# 30/30 [==============================] - ETA: 0s - loss: 0.5442 - accuracy: 0.7966
# Epoch 77: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.5442 - accuracy: 0.7966 - val_loss: 0.2557 - val_accuracy: 0.9575
# Epoch 78/1000
# 29/30 [============================>.] - ETA: 0s - loss: 0.5335 - accuracy: 0.7990
# Epoch 78: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.5346 - accuracy: 0.7987 - val_loss: 0.2508 - val_accuracy: 0.9615
# Epoch 79/1000
# 29/30 [============================>.] - ETA: 0s - loss: 0.5326 - accuracy: 0.8039
# Epoch 79: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.5330 - accuracy: 0.8035 - val_loss: 0.2525 - val_accuracy: 0.9575
# Epoch 80/1000
# 28/30 [===========================>..] - ETA: 0s - loss: 0.5489 - accuracy: 0.7958
# Epoch 80: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.5464 - accuracy: 0.7960 - val_loss: 0.2560 - val_accuracy: 0.9567
# Epoch 81/1000
# 28/30 [===========================>..] - ETA: 0s - loss: 0.5407 - accuracy: 0.7960
# Epoch 81: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.5498 - accuracy: 0.7934 - val_loss: 0.2554 - val_accuracy: 0.9543
# Epoch 82/1000
# 29/30 [============================>.] - ETA: 0s - loss: 0.5443 - accuracy: 0.7958
# Epoch 82: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.5425 - accuracy: 0.7960 - val_loss: 0.2521 - val_accuracy: 0.9543
# Epoch 83/1000
# 29/30 [============================>.] - ETA: 0s - loss: 0.5488 - accuracy: 0.7947
# Epoch 83: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.5485 - accuracy: 0.7947 - val_loss: 0.2448 - val_accuracy: 0.9583
# Epoch 84/1000
# 27/30 [==========================>...] - ETA: 0s - loss: 0.5179 - accuracy: 0.8084
# Epoch 84: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.5151 - accuracy: 0.8075 - val_loss: 0.2516 - val_accuracy: 0.9535
# Epoch 85/1000
# 22/30 [=====================>........] - ETA: 0s - loss: 0.5546 - accuracy: 0.7866
# Epoch 85: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 5ms/step - loss: 0.5479 - accuracy: 0.7936 - val_loss: 0.2465 - val_accuracy: 0.9583
# Epoch 86/1000
# 29/30 [============================>.] - ETA: 0s - loss: 0.5377 - accuracy: 0.8012
# Epoch 86: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.5369 - accuracy: 0.8011 - val_loss: 0.2460 - val_accuracy: 0.9583
# Epoch 87/1000
# 29/30 [============================>.] - ETA: 0s - loss: 0.5319 - accuracy: 0.8020
# Epoch 87: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.5326 - accuracy: 0.8011 - val_loss: 0.2463 - val_accuracy: 0.9551
# Epoch 88/1000
# 30/30 [==============================] - ETA: 0s - loss: 0.5327 - accuracy: 0.8027
# Epoch 88: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.5327 - accuracy: 0.8027 - val_loss: 0.2407 - val_accuracy: 0.9591
# Epoch 89/1000
# 28/30 [===========================>..] - ETA: 0s - loss: 0.5493 - accuracy: 0.7999
# Epoch 89: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.5471 - accuracy: 0.8001 - val_loss: 0.2411 - val_accuracy: 0.9607
# Epoch 90/1000
# 28/30 [===========================>..] - ETA: 0s - loss: 0.5275 - accuracy: 0.8078
# Epoch 90: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.5258 - accuracy: 0.8078 - val_loss: 0.2479 - val_accuracy: 0.9567
# Epoch 91/1000
# 27/30 [==========================>...] - ETA: 0s - loss: 0.5071 - accuracy: 0.8148
# Epoch 91: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.5086 - accuracy: 0.8156 - val_loss: 0.2450 - val_accuracy: 0.9535
# Epoch 92/1000
# 29/30 [============================>.] - ETA: 0s - loss: 0.5372 - accuracy: 0.7950
# Epoch 92: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.5373 - accuracy: 0.7947 - val_loss: 0.2415 - val_accuracy: 0.9519
# Epoch 93/1000
# 27/30 [==========================>...] - ETA: 0s - loss: 0.5014 - accuracy: 0.8131
# Epoch 93: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.5095 - accuracy: 0.8105 - val_loss: 0.2361 - val_accuracy: 0.9583
# Epoch 94/1000
# 28/30 [===========================>..] - ETA: 0s - loss: 0.4990 - accuracy: 0.8092
# Epoch 94: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.4967 - accuracy: 0.8105 - val_loss: 0.2356 - val_accuracy: 0.9583
# Epoch 95/1000
# 28/30 [===========================>..] - ETA: 0s - loss: 0.5180 - accuracy: 0.8064
# Epoch 95: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.5174 - accuracy: 0.8059 - val_loss: 0.2388 - val_accuracy: 0.9559
# Epoch 96/1000
# 27/30 [==========================>...] - ETA: 0s - loss: 0.5131 - accuracy: 0.8067
# Epoch 96: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.5152 - accuracy: 0.8051 - val_loss: 0.2403 - val_accuracy: 0.9551
# Epoch 97/1000
# 29/30 [============================>.] - ETA: 0s - loss: 0.5136 - accuracy: 0.8112
# Epoch 97: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.5147 - accuracy: 0.8110 - val_loss: 0.2406 - val_accuracy: 0.9527
# Epoch 98/1000
# 27/30 [==========================>...] - ETA: 0s - loss: 0.5084 - accuracy: 0.8119
# Epoch 98: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.5117 - accuracy: 0.8097 - val_loss: 0.2386 - val_accuracy: 0.9615
# Epoch 99/1000
# 27/30 [==========================>...] - ETA: 0s - loss: 0.5209 - accuracy: 0.8067
# Epoch 99: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.5212 - accuracy: 0.8038 - val_loss: 0.2379 - val_accuracy: 0.9575
# Epoch 100/1000
# 29/30 [============================>.] - ETA: 0s - loss: 0.5067 - accuracy: 0.8120
# Epoch 100: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.5058 - accuracy: 0.8123 - val_loss: 0.2374 - val_accuracy: 0.9623
# Epoch 101/1000
# 25/30 [========================>.....] - ETA: 0s - loss: 0.5325 - accuracy: 0.8012
# Epoch 101: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.5309 - accuracy: 0.8041 - val_loss: 0.2408 - val_accuracy: 0.9551
# Epoch 102/1000
# 28/30 [===========================>..] - ETA: 0s - loss: 0.5162 - accuracy: 0.8086
# Epoch 102: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.5192 - accuracy: 0.8089 - val_loss: 0.2400 - val_accuracy: 0.9519
# Epoch 103/1000
# 29/30 [============================>.] - ETA: 0s - loss: 0.5100 - accuracy: 0.8047
# Epoch 103: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.5082 - accuracy: 0.8057 - val_loss: 0.2301 - val_accuracy: 0.9567
# Epoch 104/1000
# 28/30 [===========================>..] - ETA: 0s - loss: 0.5135 - accuracy: 0.8058
# Epoch 104: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.5107 - accuracy: 0.8070 - val_loss: 0.2405 - val_accuracy: 0.9591
# Epoch 105/1000
# 28/30 [===========================>..] - ETA: 0s - loss: 0.5136 - accuracy: 0.8052
# Epoch 105: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.5178 - accuracy: 0.8019 - val_loss: 0.2361 - val_accuracy: 0.9631
# Epoch 106/1000
# 27/30 [==========================>...] - ETA: 0s - loss: 0.5249 - accuracy: 0.8090
# Epoch 106: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.5217 - accuracy: 0.8105 - val_loss: 0.2360 - val_accuracy: 0.9559
# Epoch 107/1000
# 28/30 [===========================>..] - ETA: 0s - loss: 0.5139 - accuracy: 0.8005
# Epoch 107: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.5172 - accuracy: 0.8022 - val_loss: 0.2351 - val_accuracy: 0.9607
# Epoch 108/1000
# 29/30 [============================>.] - ETA: 0s - loss: 0.4948 - accuracy: 0.8187
# Epoch 108: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.4953 - accuracy: 0.8180 - val_loss: 0.2368 - val_accuracy: 0.9535
# Epoch 109/1000
# 27/30 [==========================>...] - ETA: 0s - loss: 0.5171 - accuracy: 0.8015
# Epoch 109: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.5154 - accuracy: 0.8019 - val_loss: 0.2424 - val_accuracy: 0.9511
# Epoch 110/1000
# 28/30 [===========================>..] - ETA: 0s - loss: 0.4957 - accuracy: 0.8209
# Epoch 110: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.4943 - accuracy: 0.8212 - val_loss: 0.2328 - val_accuracy: 0.9575
# Epoch 111/1000
# 26/30 [=========================>....] - ETA: 0s - loss: 0.4874 - accuracy: 0.8236
# Epoch 111: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.4920 - accuracy: 0.8246 - val_loss: 0.2309 - val_accuracy: 0.9583
# Epoch 112/1000
# 28/30 [===========================>..] - ETA: 0s - loss: 0.5061 - accuracy: 0.8119
# Epoch 112: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.5077 - accuracy: 0.8115 - val_loss: 0.2335 - val_accuracy: 0.9567
# Epoch 113/1000
# 29/30 [============================>.] - ETA: 0s - loss: 0.4907 - accuracy: 0.8160
# Epoch 113: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.4920 - accuracy: 0.8153 - val_loss: 0.2299 - val_accuracy: 0.9623
# Epoch 114/1000
# 21/30 [====================>.........] - ETA: 0s - loss: 0.5144 - accuracy: 0.7961
# Epoch 114: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.5147 - accuracy: 0.8035 - val_loss: 0.2369 - val_accuracy: 0.9575
# Epoch 115/1000
# 30/30 [==============================] - ETA: 0s - loss: 0.5071 - accuracy: 0.8067
# Epoch 115: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.5071 - accuracy: 0.8067 - val_loss: 0.2297 - val_accuracy: 0.9567
# Epoch 116/1000
# 27/30 [==========================>...] - ETA: 0s - loss: 0.4935 - accuracy: 0.8197
# Epoch 116: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.4984 - accuracy: 0.8188 - val_loss: 0.2286 - val_accuracy: 0.9591
# Epoch 117/1000
# 29/30 [============================>.] - ETA: 0s - loss: 0.5067 - accuracy: 0.8074
# Epoch 117: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.5058 - accuracy: 0.8081 - val_loss: 0.2361 - val_accuracy: 0.9535
# Epoch 118/1000
# 28/30 [===========================>..] - ETA: 0s - loss: 0.5032 - accuracy: 0.8086
# Epoch 118: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.4978 - accuracy: 0.8113 - val_loss: 0.2330 - val_accuracy: 0.9615
# Epoch 119/1000
# 29/30 [============================>.] - ETA: 0s - loss: 0.4861 - accuracy: 0.8093
# Epoch 119: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.4855 - accuracy: 0.8097 - val_loss: 0.2257 - val_accuracy: 0.9623
# Epoch 120/1000
# 28/30 [===========================>..] - ETA: 0s - loss: 0.5084 - accuracy: 0.8025
# Epoch 120: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.5092 - accuracy: 0.8022 - val_loss: 0.2285 - val_accuracy: 0.9591
# Epoch 121/1000
# 28/30 [===========================>..] - ETA: 0s - loss: 0.4920 - accuracy: 0.8195
# Epoch 121: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.4935 - accuracy: 0.8198 - val_loss: 0.2305 - val_accuracy: 0.9551
# Epoch 122/1000
# 29/30 [============================>.] - ETA: 0s - loss: 0.5027 - accuracy: 0.8125
# Epoch 122: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.5007 - accuracy: 0.8134 - val_loss: 0.2226 - val_accuracy: 0.9615
# Epoch 123/1000
# 27/30 [==========================>...] - ETA: 0s - loss: 0.5007 - accuracy: 0.8082
# Epoch 123: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.4988 - accuracy: 0.8086 - val_loss: 0.2182 - val_accuracy: 0.9631
# Epoch 124/1000
# 25/30 [========================>.....] - ETA: 0s - loss: 0.4992 - accuracy: 0.8081
# Epoch 124: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.4930 - accuracy: 0.8107 - val_loss: 0.2230 - val_accuracy: 0.9559
# Epoch 125/1000
# 25/30 [========================>.....] - ETA: 0s - loss: 0.4801 - accuracy: 0.8219
# Epoch 125: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.4885 - accuracy: 0.8193 - val_loss: 0.2216 - val_accuracy: 0.9623
# Epoch 126/1000
# 23/30 [======================>.......] - ETA: 0s - loss: 0.4989 - accuracy: 0.8064
# Epoch 126: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 5ms/step - loss: 0.5011 - accuracy: 0.8065 - val_loss: 0.2199 - val_accuracy: 0.9599
# Epoch 127/1000
# 26/30 [=========================>....] - ETA: 0s - loss: 0.5007 - accuracy: 0.8122
# Epoch 127: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.5028 - accuracy: 0.8121 - val_loss: 0.2180 - val_accuracy: 0.9607
# Epoch 128/1000
# 27/30 [==========================>...] - ETA: 0s - loss: 0.4796 - accuracy: 0.8203
# Epoch 128: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.4747 - accuracy: 0.8230 - val_loss: 0.2238 - val_accuracy: 0.9647
# Epoch 129/1000
# 28/30 [===========================>..] - ETA: 0s - loss: 0.4801 - accuracy: 0.8192
# Epoch 129: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.4840 - accuracy: 0.8172 - val_loss: 0.2249 - val_accuracy: 0.9639
# Epoch 130/1000
# 27/30 [==========================>...] - ETA: 0s - loss: 0.4881 - accuracy: 0.8166
# Epoch 130: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.4949 - accuracy: 0.8134 - val_loss: 0.2258 - val_accuracy: 0.9551
# Epoch 131/1000
# 26/30 [=========================>....] - ETA: 0s - loss: 0.4939 - accuracy: 0.8167
# Epoch 131: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.4914 - accuracy: 0.8172 - val_loss: 0.2266 - val_accuracy: 0.9551
# Epoch 132/1000
# 24/30 [=======================>......] - ETA: 0s - loss: 0.5023 - accuracy: 0.8174
# Epoch 132: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 5ms/step - loss: 0.5008 - accuracy: 0.8153 - val_loss: 0.2280 - val_accuracy: 0.9575
# Epoch 133/1000
# 25/30 [========================>.....] - ETA: 0s - loss: 0.4830 - accuracy: 0.8175
# Epoch 133: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.4812 - accuracy: 0.8190 - val_loss: 0.2308 - val_accuracy: 0.9527
# Epoch 134/1000
# 27/30 [==========================>...] - ETA: 0s - loss: 0.4861 - accuracy: 0.8131
# Epoch 134: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.4826 - accuracy: 0.8148 - val_loss: 0.2320 - val_accuracy: 0.9567
# Epoch 135/1000
# 29/30 [============================>.] - ETA: 0s - loss: 0.4896 - accuracy: 0.8198
# Epoch 135: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.4886 - accuracy: 0.8196 - val_loss: 0.2274 - val_accuracy: 0.9599
# Epoch 136/1000
# 28/30 [===========================>..] - ETA: 0s - loss: 0.4803 - accuracy: 0.8203
# Epoch 136: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.4825 - accuracy: 0.8190 - val_loss: 0.2255 - val_accuracy: 0.9583
# Epoch 137/1000
# 29/30 [============================>.] - ETA: 0s - loss: 0.4954 - accuracy: 0.8147
# Epoch 137: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.4942 - accuracy: 0.8156 - val_loss: 0.2286 - val_accuracy: 0.9575
# Epoch 138/1000
# 28/30 [===========================>..] - ETA: 0s - loss: 0.4868 - accuracy: 0.8119
# Epoch 138: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.4818 - accuracy: 0.8134 - val_loss: 0.2271 - val_accuracy: 0.9511
# Epoch 139/1000
# 27/30 [==========================>...] - ETA: 0s - loss: 0.5047 - accuracy: 0.8137
# Epoch 139: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.5017 - accuracy: 0.8137 - val_loss: 0.2284 - val_accuracy: 0.9527
# Epoch 140/1000
# 27/30 [==========================>...] - ETA: 0s - loss: 0.4920 - accuracy: 0.8180
# Epoch 140: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.4913 - accuracy: 0.8174 - val_loss: 0.2318 - val_accuracy: 0.9519
# Epoch 141/1000
# 30/30 [==============================] - ETA: 0s - loss: 0.4937 - accuracy: 0.8158
# Epoch 141: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.4937 - accuracy: 0.8158 - val_loss: 0.2282 - val_accuracy: 0.9535
# Epoch 142/1000
# 29/30 [============================>.] - ETA: 0s - loss: 0.4878 - accuracy: 0.8168
# Epoch 142: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.4884 - accuracy: 0.8169 - val_loss: 0.2236 - val_accuracy: 0.9583
# Epoch 143/1000
# 27/30 [==========================>...] - ETA: 0s - loss: 0.4843 - accuracy: 0.8177
# Epoch 143: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.4779 - accuracy: 0.8212 - val_loss: 0.2282 - val_accuracy: 0.9559
# Epoch 144/1000
# 26/30 [=========================>....] - ETA: 0s - loss: 0.4763 - accuracy: 0.8200
# Epoch 144: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.4795 - accuracy: 0.8169 - val_loss: 0.2258 - val_accuracy: 0.9599
# Epoch 145/1000
# 27/30 [==========================>...] - ETA: 0s - loss: 0.4724 - accuracy: 0.8197
# Epoch 145: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.4755 - accuracy: 0.8177 - val_loss: 0.2205 - val_accuracy: 0.9623
# Epoch 146/1000
# 28/30 [===========================>..] - ETA: 0s - loss: 0.4742 - accuracy: 0.8237
# Epoch 146: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.4734 - accuracy: 0.8228 - val_loss: 0.2222 - val_accuracy: 0.9615
# Epoch 147/1000
# 29/30 [============================>.] - ETA: 0s - loss: 0.4729 - accuracy: 0.8265
# Epoch 147: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.4723 - accuracy: 0.8265 - val_loss: 0.2250 - val_accuracy: 0.9535
# Epoch 147: early stopping

# %%
# モデル評価
val_loss, val_acc = model.evaluate(X_test, y_test, batch_size=128)
# Out:
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2250 - accuracy: 0.9535

# %%
# 保存したモデルのロード
model = tf.keras.models.load_model(model_save_path)

# %%
# 推論テスト
predict_result = model.predict(np.array([X_test[0]]))
print(np.squeeze(predict_result))
print(np.argmax(np.squeeze(predict_result)))
# Out:
# 1/1 [==============================] - 0s 50ms/step
# [1.2553473e-04 9.9861741e-01 1.2563085e-03 6.9375216e-07]
# 1

# %% [markdown]
# # 混同行列

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report

def print_confusion_matrix(y_true, y_pred, report=True):
    labels = sorted(list(set(y_true)))
    cmx_data = confusion_matrix(y_true, y_pred, labels=labels)
    
    df_cmx = pd.DataFrame(cmx_data, index=labels, columns=labels)
 
    fig, ax = plt.subplots(figsize=(7, 6))
    sns.heatmap(df_cmx, annot=True, fmt='g' ,square=False)
    ax.set_ylim(len(set(y_true)), 0)
    plt.show()
    
    if report:
        print('Classification Report')
        print(classification_report(y_test, y_pred))

Y_pred = model.predict(X_test)
y_pred = np.argmax(Y_pred, axis=1)

print_confusion_matrix(y_test, y_pred)
# Out:
# 39/39 [==============================] - 0s 1ms/step
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99       397
#            1       0.99      0.92      0.96       358
#            2       0.88      0.98      0.93       355
#            3       1.00      0.86      0.92       138
#
#     accuracy                           0.95      1248
#    macro avg       0.96      0.94      0.95      1248
# weighted avg       0.96      0.95      0.95      1248

# %% [markdown]
# # Tensorflow-Lite用のモデルへ変換

# %%
# 推論専用のモデルとして保存
model.save(model_save_path, include_optimizer=False)

# %%
# モデルを変換(量子化)
tflite_save_path = 'model/keypoint_classifier/keypoint_classifier.tflite'

converter = tf.lite.TFLiteConverter.from_keras_model(model)
converter.optimizations = [tf.lite.Optimize.DEFAULT]
tflite_quantized_model = converter.convert()

open(tflite_save_path, 'wb').write(tflite_quantized_model)
# Out:
# INFO:tensorflow:Assets written to: C:\Users\Omar\AppData\Local\Temp\tmp7luf9spn\assets
# INFO:tensorflow:Assets written to: C:\Users\Omar\AppData\Local\Temp\tmp7luf9spn\assets
# 6624

# %% [markdown]
# # 推論テスト

# %%
interpreter = tf.lite.Interpreter(model_path=tflite_save_path)
interpreter.allocate_tensors()

# %%
# 入出力テンソルを取得
input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()

# %%
interpreter.set_tensor(input_details[0]['index'], np.array([X_test[0]]))

# %%
# %%time
# 推論実施
interpreter.invoke()
tflite_results = interpreter.get_tensor(output_details[0]['index'])
# Out:
# Wall time: 0 ns

# %%
print(np.squeeze(tflite_results))
print(np.argmax(np.squeeze(tflite_results)))
# Out:
# [1.2553461e-04 9.9861741e-01 1.2563062e-03 6.9374954e-07]
# 1
